# %% [markdown]
# # Chapter 2
# ## 2.4 Exercises - Applied

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# ## 8.

# %% [markdown]
# ### (a) Load data

# %%
college = pd.read_csv('../../../DataSets/College.csv')

# %% [markdown]
# ### (b) Look at data; set row names to index

# %%
college
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
college.set_index('Unnamed: 0', inplace=True)
college
# Out:
#                                         Private   Apps  Accept  Enroll  \
# Unnamed: 0
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# Alaska Pacific University                   Yes    193     146      55
# Albertson College                           Yes    587     479     158
# Albertus Magnus College                     Yes    353     340     103
# Albion College                              Yes   1899    1720     489
# Albright College                            Yes   1038     839     227
# Alderson-Broaddus College                   Yes    582     498     172
# Alfred University                           Yes   1732    1425     472
# Allegheny College                           Yes   2652    1900     484
# ...

# %% [markdown]
# ### (c)
# #### (i) Numerical summary of data set

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# #### (ii) Scatter plot matrix

# %%
# %matplotlib inline
scatter_matrix(college[0:10], alpha=0.2, color='k', figsize=(20, 20), diagonal='hist')
plt.suptitle('Scatter-matrix, similar to pairs() in R', fontsize = 20, fontweight='bold')
plt.show()

# %% [markdown]
# #### (iii) Box plot Outstate versus Private

# %%
sns.boxplot(college.Private, college.Outstate)

# %% [markdown]
# #### (iv)  Create qualitative variable Elite by binning the Top10perc variable. Yes if proportion of students coming from top 10% exceeds 50% and No if not. Nummerical summary of Elite and plot Outstate versus Elite. Box plot Outstate versus Elite

# %%
college['Elite'] = college['Top10perc'].apply(lambda x: 'Yes' if x > 50 else 'No')
college.rename(columns={'Grad.Rate': 'GradRate', 'P.Undergrad': 'PUndergrad', 'F.Undergrad': 'FUndergrad'}, inplace=True)
college
# Out:
#                                         Private   Apps  Accept  Enroll  \
# Unnamed: 0
# Abilene Christian University                Yes   1660    1232     721
# Adelphi University                          Yes   2186    1924     512
# Adrian College                              Yes   1428    1097     336
# Agnes Scott College                         Yes    417     349     137
# Alaska Pacific University                   Yes    193     146      55
# Albertson College                           Yes    587     479     158
# Albertus Magnus College                     Yes    353     340     103
# Albion College                              Yes   1899    1720     489
# Albright College                            Yes   1038     839     227
# Alderson-Broaddus College                   Yes    582     498     172
# Alfred University                           Yes   1732    1425     472
# Allegheny College                           Yes   2652    1900     484
# ...

# %%
college['Elite'].describe()
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
sns.boxplot(college.Elite, college.Outstate)

# %% [markdown]
# ### (v) Histograms subplots

# %%
college.hist(figsize=(20, 20), ec='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1287ab310>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12735e750>]], dtype=object)

# %% [markdown]
# ### (vi) Explore data; provide brief summary

# %%
college.plot.scatter('Accept', 'Enroll')

# %% [markdown]
# Not all students accepted to the undergrad courses have enrolled. It's probably possible to apply to more than one university.

# %%
#college.sort_values(by='Expend', ascending=0) 
#college.iloc[0:20].plot(subplots = True, figsize=(20,20), style = 'o')
#college.iloc[0:20].plot(subplots = True, figsize=(20,20), kind='bar')
college.sort_values(by='Expend', ascending=0).iloc[0:10].plot(subplots = True, figsize=(20,25), 
                                                              kind='bar', legend = False)
plt.subplots_adjust(hspace = 0.5)

# %% [markdown]
# The top 10 universities that have higher instutitional expenditure per student diverge overall.

# %%
college.sort_values(by='Expend', ascending=0)[['FUndergrad', 'PUndergrad']].iloc[0:10].plot(subplots = True, 
                                                                                            figsize=(20,20), kind='bar')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ea18990>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x121b4aa10>], dtype=object)

# %% [markdown]
# The top 10 universities that have higher instutitional expenditure per student, Havard Univeristy has more full-time students, around 7000. Antioch University has the lowest number of full-time students (less than 1000). Antioch University and MIT have the lowest number of part-time students, less than 200 for both.

# %%
college.sort_values(by='Expend', ascending=0)[[ 'GradRate']].iloc[0:10].plot(subplots = True, 
                                                                                            figsize=(20,20), kind='bar')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11e2a8690>], dtype=object)

# %% [markdown]
# Out of the top 10 universities that have higher instutitional expenditure per student, only Antioch University has a graduation rate of less than 80%.

# %%
college.sort_values(by='Expend', ascending=1).iloc[0:10].plot(subplots = True, fontsize=15,figsize=(20,25), 
                                                              kind='bar', legend = False)
plt.subplots_adjust(hspace = 0.5)

# %% [markdown]
# The bottom 10 universities that have lower instutitional expenditure per student diverge less than the top 10.

# %%
college.sort_values(by='Expend', ascending=1)[['FUndergrad', 'PUndergrad']].iloc[0:10].plot(subplots = True,fontsize=15, 
                                                                                            figsize=(20,20), kind='bar')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x123c5bfd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x123c2dfd0>], dtype=object)

# %% [markdown]
# The bottom 10 universities that have lowest instutitional expenditure per student, Jamestown College has more full-time students (about 10000). Central Wesleyan College has the lowest number of full-time students (less than 2000). Jamestown College, Central Wesleyan College and Fladger Colelge have the lowest number of part-time students, less than 500 for all 3.

# %%
college.sort_values(by='Expend', ascending=1)[[ 'GradRate']].iloc[0:10].plot(subplots = True, fontsize=15, 
                                                                                            figsize=(20,20), kind='bar')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x122d8e250>], dtype=object)

# %% [markdown]
# The bottom 10 universities that have lowest instutitional expenditure per student, only Lindenwood College has a graduate rate of above 80%.

# %%
CollegeHSpend = college.sort_values(by='Expend', ascending=0).iloc[0:10]
CollegeLSpend = college.sort_values(by='Expend', ascending=1).iloc[0:10]

# %%
plt.figure(1, figsize=(15,20))
plt.subplot(2,2,1)
CollegeHSpend.sort_values(by='FUndergrad', ascending=0)[['GradRate']].plot(subplots = True, figsize=(15,20), kind='bar', ax=plt.gca())
plt.title('High Expend')
plt.subplot(2,2,2)
CollegeLSpend.sort_values(by='FUndergrad', ascending=1)[['GradRate']].plot(subplots = True,figsize=(15,20), kind='bar', ax=plt.gca())
plt.title('Low Expend')
plt.suptitle("Graduation Rate")

# %%
#CollegeHSpend.sort_values(by='FUndergrad', ascending=0)[['GradRate']].plot(subplots = True,figsize=(20,20), kind='bar')
#CollegeHSpend[['PUndergrad', 'FUndergrad']].plot(subplots = True,figsize=(20,20), kind='bar')

# %%
plt.figure(1, figsize=(15,20))
plt.subplot(2,2,1)
CollegeHSpend.sort_values(by='PUndergrad', ascending=0)[['GradRate']].plot(subplots = True,figsize=(15,20), kind='bar', ax=plt.gca())
plt.title('High Expend')
plt.subplot(2,2,2)
CollegeLSpend.sort_values(by='PUndergrad', ascending=1)[['GradRate']].plot(subplots = True,figsize=(15,20), kind='bar', ax=plt.gca())
plt.title('Low Expend')
plt.suptitle("Graduation Rate")

# %% [markdown]
# The top 10 universities in instructional expenditure per student has a better graduation rate than the lower 10.

# %%
CollegeHSpend[['Apps','Accept', 'PUndergrad', 'FUndergrad']].plot(figsize=(20,10), kind='bar', ylim=(0,14000))
plt.legend(['No. Application', 'No. Applications Accepted', 'No. Part-time Undergrads', 'No. Full-time Undergrads'])

# %%
CollegeLSpend[['Apps','Accept', 'PUndergrad', 'FUndergrad']].plot(figsize=(20,10), kind='bar', ylim=(0,14000))
plt.legend(['No. Application', 'No. Applications Accepted', 'No. Part-time Undergrads', 'No. Full-time Undergrads'])

# %%
CollegeHSpend[['S.F.Ratio', 'GradRate']].plot(figsize=(20,10), kind='bar')

# %%
CollegeLSpend[['S.F.Ratio', 'GradRate']].plot(figsize=(20,10), kind='bar')

# %%
CollegeHSpend[['PhD', 'Terminal', 'GradRate']].plot(figsize=(20,10), kind='bar')

# %%
CollegeLSpend[['PhD', 'Terminal', 'GradRate']].plot(figsize=(20,10), kind='bar')

# %%
CollegeHSpend[['Outstate', 'Room.Board', 'Books', 'Personal', 'Expend']].plot(figsize=(20,10),fontsize=15, kind='bar', ylim=(0,60000))

# %%
CollegeLSpend[['Outstate', 'Room.Board', 'Books', 'Personal', 'Expend']].plot(figsize=(20,10), fontsize=15, kind='bar', ylim=(0,60000))

# %%
CollegeHSpend[['Outstate', 'Room.Board', 'Books', 'Personal']].plot(figsize=(20,10),fontsize=15, kind='bar', ylim=(0,20000))

# %%
CollegeLSpend[['Outstate', 'Room.Board', 'Books', 'Personal']].plot(figsize=(20,10), fontsize = 15,kind='bar', ylim=(0,20000))

# %% [markdown]
# ## 9.

# %%
Auto = pd.read_csv('../../../DataSets/Auto.csv', na_values=['?'])
Auto.dropna()
Auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %% [markdown]
# ### (a) Quantitative vs qualitative predictors

# %%
Auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  397.000000  397.000000    397.000000  392.000000   397.000000
# mean    23.515869    5.458438    193.532746  104.469388  2970.261965
# std      7.825804    1.701577    104.379583   38.491160   847.904119
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.000000   75.000000  2223.000000
# 50%     23.000000    4.000000    146.000000   93.500000  2800.000000
# 75%     29.000000    8.000000    262.000000  126.000000  3609.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    397.000000  397.000000  397.000000
# mean      15.555668   75.994962    1.574307
# std        2.749995    3.690005    0.802549
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# Qualitative: 'name' and 'origin'.
# All the other ones are quantitative.  'Cilinders' could be treated as qualitative

# %% [markdown]
# ### (b) Range of each quantitative predictor

# %%
Auto.iloc[:,[0,1,2,3,4,5,6]].max()
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          5140.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %%
Auto.iloc[:,[0,1,2,3,4,5,6]].min()
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# dtype: float64

# %% [markdown]
# ### (c) Mean and standard deviation of quantitative predictor

# %%
Auto.iloc[:,[0,1,2,3,4,5,6]].std()
# Out:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# horsepower       38.491160
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# dtype: float64

# %%
Auto.iloc[:,[0,1,2,3,4,5,6]].mean()
# Out:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# horsepower       104.469388
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# dtype: float64

# %% [markdown]
# ### (d) Remove 10th through 85th observations. Mean, range and standard deviation

# %%
Auto_subset=Auto
Auto_subset.drop(Auto_subset.index[11:87],inplace=True)
Auto_subset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
Auto_subset.iloc[:,[0,1,2,3,4,5,6]].max()
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# horsepower       230.0
# weight          4997.0
# acceleration      24.8
# year              82.0
# dtype: float64

# %%
Auto_subset.iloc[:,[0,1,2,3,4,5,6]].min()
# Out:
# mpg               11.0
# cylinders          3.0
# displacement      68.0
# horsepower        46.0
# weight          1649.0
# acceleration       8.5
# year              70.0
# dtype: float64

# %%
Auto_subset.iloc[:,[0,1,2,3,4,5,6]].mean()
# Out:
# mpg               24.447975
# cylinders          5.370717
# displacement     187.420561
# horsepower       101.066246
# weight          2932.844237
# acceleration      15.704361
# year              77.133956
# dtype: float64

# %%
Auto_subset.iloc[:,[0,1,2,3,4,5,6]].std()
# Out:
# mpg               7.895992
# cylinders         1.653486
# displacement    100.249972
# horsepower       36.106716
# weight          809.350627
# acceleration      2.715013
# year              3.145056
# dtype: float64

# %% [markdown]
# ### (e) Investigate predictors graphically

# %%
axes = scatter_matrix(Auto.iloc[:,[0,1,2,3,4,5,6]], alpha=0.2, color='k', figsize=(20, 20), diagonal='hist')
plt.suptitle('Scatter-matrix, similar to pairs() in R', fontsize = 15, fontweight='bold')
corr = Auto.corr().as_matrix()
for i, j in zip(*plt.np.triu_indices_from(axes, k=1)):
    axes[i, j].annotate("%.3f" %corr[i,j], (0.8, 0.8), xycoords='axes fraction', ha='center', va='center')
# for ax in axes.ravel():
#     ax.set_xlabel(ax.get_xlabel(), fontsize = 20, rotation = 90)
#     ax.set_ylabel(ax.get_ylabel(), fontsize = 20, rotation = 0)
plt.show()

# %%
sns.boxplot(Auto.cylinders, Auto.acceleration)

# %% [markdown]
# More cylinders does not necessarily mean more acceleration

# %%
sns.boxplot(Auto.cylinders, Auto.horsepower)

# %% [markdown]
# More cylinders = more horsepower

# %%
Auto.plot.scatter('mpg', 'year')

# %% [markdown]
# Cars got more efficient over the years

# %%
Auto.plot.scatter('mpg', 'weight')

# %% [markdown]
# lighter car = more miles per gallon (more efficient)

# %%
Auto.plot.scatter('mpg', 'cylinders')

# %% [markdown]
# More cylinders = less mpg

# %% [markdown]
# ### (f) Predict mpgon the basis of the other variables

# %%
AutoMPG = Auto.sort_values(by='mpg', ascending=0)

# %%
Auto.plot.scatter('mpg', 'year')
Auto.plot.scatter('mpg', 'cylinders')
Auto.plot.scatter('mpg', 'displacement')
Auto.plot.scatter('mpg', 'horsepower')
Auto.plot.scatter('mpg', 'weight')
Auto.plot.scatter('mpg', 'acceleration')

# %% [markdown]
# more cylinders = less mpg
# more displacement, horsepower and weight = less mpg
# more acceleration = more mpg

# %% [markdown]
# ## (10) Boston housing data

# %% [markdown]
# ### (a) Load Boston data set, read data information and answer: how many rows , how many columns, what rows and columns represent

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from sklearn import cross_validation
from sklearn import metrics
from sklearn import preprocessing

# %%
from sklearn.datasets import load_boston
boston = load_boston()
print( "type of boston = ", type(boston))
# Out:
# type of boston =  <class 'sklearn.datasets.base.Bunch'>

# %%
 print( boston.DESCR )
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %% [markdown]
# 506 rows and 14 columns. Rows represent the observations (506 observations) and columns represent the variables (14 variables)

# %% [markdown]
# ### (b) Scatter plots

# %%
bostonDF = pd.DataFrame( boston.data )
bostonDF.columns = boston.feature_names
bostonDF.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
scatter_matrix(bostonDF, alpha=0.2, color='k', figsize=(20, 20), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1347a8f50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a468a90>]], dtype=object)

# %% [markdown]
# crim grows with increase of nox, age, ptratio
# zn grows with increase of rm, dis, medv
# indus grows with increase of ratio and ptrario
# nox grows with increase of age, ptratio, lstat

# %%
bostonDF.plot.scatter('ZN', 'CRIM')
bostonDF.plot.scatter('INDUS', 'CRIM')
bostonDF.plot.scatter('CHAS', 'CRIM')
bostonDF.plot.scatter('NOX', 'CRIM')
bostonDF.plot.scatter('RM', 'CRIM')

# %%
bostonDF.plot.scatter('AGE', 'CRIM')
bostonDF.plot.scatter('DIS', 'CRIM')
bostonDF.plot.scatter('RAD', 'CRIM')

# %%
bostonDF.plot.scatter('TAX', 'CRIM')
bostonDF.plot.scatter('PTRATIO', 'CRIM')
bostonDF.plot.scatter('B', 'CRIM')
bostonDF.plot.scatter('LSTAT', 'CRIM')

# %%
scatter_matrix(bostonDF.iloc[:,[0,5,7,8,10]], alpha=0.2, color='k', figsize=(20, 20), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13d04c150>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e1fc450>]], dtype=object)

# %%
scatter_matrix(bostonDF.loc[:,['INDUS', 'TAX', 'LSTAT', 'DIS']], alpha=0.2, color='k', figsize=(20, 20), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13e797ed0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f5ef2d0>]], dtype=object)

# %% [markdown]
# Higher pupil-teacher ratio seems to relates to higher crime. There is more crime closer to the employment centres.
# There are more non-retail business nearer the Boston eployment centers, where property tax is higher

# %% [markdown]
# ### (c) Predictors associated with per capita crime rate?

# %% [markdown]
# (see scatter plots above)

# %% [markdown]
# higher pupil-teacher ratio = more crime;
# older homes = more crime;
# closer to employment centres = more crime;
# more acess to radial highways = more crime;
# higher property-tax = more crime;
# lower the median value of owner-occupied homes = more crime

# %% [markdown]
# ### (d)

# %% [markdown]
# Suburbs with high crime rate?

# %%
bostonDF['CRIM'].plot.hist()

bostonDF[bostonDF.CRIM<=80]['CRIM'].plot.hist(ec = 'black', bins = 30)

# %% [markdown]
# per capita crime rate by town is low for most of the towns (see frequency). However some towns deal with very high crime rate per capita.

# %% [markdown]
# Tax rates?

# %%
bostonDF['TAX'].plot.hist(ec = 'black', bins = 50)

# %% [markdown]
# Only a few properties-tax rate is above 700. There is a large number of property-tax rate between 600 and 700, as well a large number of property-tax rate below 500.

# %%
bostonDF['PTRATIO'].plot.hist(ec = 'black', bins = 50)

# %% [markdown]
# High Pupil-teacher ratio.

# %%
HighCrime = bostonDF.sort_values(by='CRIM', ascending=0).iloc[0:10]
HighCrime[['CRIM', 'TAX', 'PTRATIO']].plot(figsize=(20,10), fontsize = 15,kind='bar', ylim=(0,700))

# %%
HighTax = bostonDF.sort_values(by='TAX', ascending=0).iloc[0:10]
HighTax[['CRIM', 'TAX', 'PTRATIO']].plot(figsize=(20,10), fontsize = 15,kind='bar', ylim=(0,800))

# %%
HighPupilTeacher = bostonDF.sort_values(by='PTRATIO', ascending=0).iloc[0:10]
HighPupilTeacher[['CRIM', 'TAX', 'PTRATIO']].plot(figsize=(20,10), fontsize = 15,kind='bar', ylim=(0,500))

# %% [markdown]
# ### (e) How many suburbs bound the river

# %%
bostonDF['CHAS'].value_counts()
# Out:
# 0.0    471
# 1.0     35
# Name: CHAS, dtype: int64

# %% [markdown]
# 35 suburbs

# %% [markdown]
# ### (f) Median pupil-teacher ratio

# %%
bostonDF.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# 19.05
